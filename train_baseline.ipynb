# %%
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow import keras 
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.callbacks import ModelCheckpoint, TensorBoard, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.models import load_model

from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import cv2
import os


import warnings
warnings.filterwarnings("ignore")

# %%
# Define params and helpers
xlsx_path = './ODIR_dataset/ODIR-5K_Training_Annotations(Updated)_V2.xlsx'
data_dir = './ODIR_dataset/ODIR-5K_Training_Dataset/'

classes = ['N', 'D', 'G', 'C', 'A', 'H', 'M', 'O']
img_size = (160, 160)

# %%
df = pd.read_excel(xlsx_path)
df[:5]
# Out:
#    ID  Patient Age Patient Sex Left-Fundus Right-Fundus  \
# 0   0           69      Female  0_left.jpg  0_right.jpg
# 1   1           57        Male  1_left.jpg  1_right.jpg
# 2   2           42        Male  2_left.jpg  2_right.jpg
# 3   3           66        Male  3_left.jpg  3_right.jpg
# 4   4           53        Male  4_left.jpg  4_right.jpg
#
#                             Left-Diagnostic Keywords  \
# 0                                           cataract
# 1                                      normal fundus
# 2  laser spot，moderate non proliferative retinopathy
# 3                                      normal fundus
# 4                        macular epiretinal membrane
#
#                 Right-Diagnostic Keywords  N  D  G  C  A  H  M  O
# 0                           normal fundus  0  0  0  1  0  0  0  0
# 1                           normal fundus  1  0  0  0  0  0  0  0
# 2  moderate non proliferative retinopathy  0  1  0  0  0  0  0  1
# 3         branch retinal artery occlusion  0  0  0  0  0  0  0  1
# 4       mild nonproliferative retinopathy  0  1  0  0  0  0  0  1

# %%
def get_input(path):
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    return(img)

# %%
def get_output(df):
    labels = df[classes].values.tolist()
    return(labels)

# %%
def preprocess_input(image):
    img_resized = cv2.resize(image, img_size)
    return(img_resized)

# %%
def image_generator(df, batch_size=64):
    df = df.sample(frac=1).reset_index(drop=True)
    img_path_left_list = df['Left-Fundus'].values.tolist()
    img_path_right_list = df['Right-Fundus'].values.tolist()
    labels = get_output(df[classes])
    n_data = len(df)
    count = 0
    
    while True:
        # Select files (paths/indices) for the batch
        
        batch_input_left = []
        batch_input_right = []
        batch_output = [] 
          
        # Read in each input, perform preprocessing and get labels
        for i in range(batch_size):
            idx = count % n_data
            img_path_left = os.path.join(data_dir, img_path_left_list[idx])
            img_path_right = os.path.join(data_dir, img_path_right_list[idx])
            input_left = get_input(img_path_left)
            input_right = get_input(img_path_right)
            output = labels[idx]
            
            input_left = preprocess_input(image=input_left)
            input_right = preprocess_input(image=input_right)
            batch_input_left += [input_left]
            batch_input_right += [input_right]
            batch_output += [output]
        # Return a tuple of (input,output) to feed the network
        batch_x_left = np.array(batch_input_left)
        batch_x_right = np.array(batch_input_right)
        batch_y = np.array(batch_output)
        
        yield([batch_x_left, batch_x_right], batch_y )

# %%
def create_model():
    # left head
    base_model_left = ResNet50(include_top=False, pooling='avg', weights='imagenet')
    for layer in base_model_left.layers:
        layer._name = layer.name + '_l'
        layer.trainable = True
    x_l = base_model_left.output
    
    # right head
    base_model_right = ResNet50(include_top=False, pooling='avg', weights='imagenet')
    
    for layer in base_model_right.layers:
        layer._name = layer.name + '_r'
        layer.trainable = True
    x_r = base_model_right.output
    
    x = keras.layers.concatenate([x_l, x_r])
    x = keras.layers.Dropout(0.2)(x)
    x = keras.layers.Dense(512)(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Activation('relu')(x)
    x = keras.layers.Dense(512)(x)
    x = keras.layers.BatchNormalization()(x)
    x = keras.layers.Activation('relu')(x)
    x = keras.layers.Dropout(0.2)(x)
    out = keras.layers.Dense(len(classes), activation='sigmoid')(x)
    model = keras.models.Model(inputs=[base_model_left.input, base_model_right.input], outputs=out)
    return model

# %%
model = create_model()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1104 18:19:08.381942 20084 deprecation.py:506] From C:\Users\Natthawat\Anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1_l (InputLayer)          [(None, None, None,  0
# __________________________________________________________________________________________________
# input_2_r (InputLayer)          [(None, None, None,  0
# __________________________________________________________________________________________________
# conv1_pad_l (ZeroPadding2D)     (None, None, None, 3 0           input_1_l[0][0]
# __________________________________________________________________________________________________
# conv1_pad_r (ZeroPadding2D)     (None, None, None, 3 0           input_2_r[0][0]
# __________________________________________________________________________________________________
# conv1_l (Conv2D)                (None, None, None, 6 9472        conv1_pad_l[0][0]
# __________________________________________________________________________________________________
# conv1_r (Conv2D)                (None, None, None, 6 9472        conv1_pad_r[0][0]
# __________________________________________________________________________________________________
# bn_conv1_l (BatchNormalization) (None, None, None, 6 256         conv1_l[0][0]
# __________________________________________________________________________________________________
# bn_conv1_r (BatchNormalization) (None, None, None, 6 256         conv1_r[0][0]
# __________________________________________________________________________________________________
# activation_l (Activation)       (None, None, None, 6 0           bn_conv1_l[0][0]
# __________________________________________________________________________________________________
# activation_49_r (Activation)    (None, None, None, 6 0           bn_conv1_r[0][0]
# __________________________________________________________________________________________________
# pool1_pad_l (ZeroPadding2D)     (None, None, None, 6 0           activation_l[0][0]
# __________________________________________________________________________________________________
# pool1_pad_r (ZeroPadding2D)     (None, None, None, 6 0           activation_49_r[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_l (MaxPooling2D)  (None, None, None, 6 0           pool1_pad_l[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1_r (MaxPooling2D (None, None, None, 6 0           pool1_pad_r[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a_l (Conv2D)       (None, None, None, 6 4160        max_pooling2d_l[0][0]
# __________________________________________________________________________________________________
# res2a_branch2a_r (Conv2D)       (None, None, None, 6 4160        max_pooling2d_1_r[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a_l (BatchNormaliza (None, None, None, 6 256         res2a_branch2a_l[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2a_r (BatchNormaliza (None, None, None, 6 256         res2a_branch2a_r[0][0]
# __________________________________________________________________________________________________
# activation_1_l (Activation)     (None, None, None, 6 0           bn2a_branch2a_l[0][0]
# __________________________________________________________________________________________________
# activation_50_r (Activation)    (None, None, None, 6 0           bn2a_branch2a_r[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b_l (Conv2D)       (None, None, None, 6 36928       activation_1_l[0][0]
# __________________________________________________________________________________________________
# res2a_branch2b_r (Conv2D)       (None, None, None, 6 36928       activation_50_r[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b_l (BatchNormaliza (None, None, None, 6 256         res2a_branch2b_l[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2b_r (BatchNormaliza (None, None, None, 6 256         res2a_branch2b_r[0][0]
# __________________________________________________________________________________________________
# activation_2_l (Activation)     (None, None, None, 6 0           bn2a_branch2b_l[0][0]
# __________________________________________________________________________________________________
# activation_51_r (Activation)    (None, None, None, 6 0           bn2a_branch2b_r[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c_l (Conv2D)       (None, None, None, 2 16640       activation_2_l[0][0]
# __________________________________________________________________________________________________
# res2a_branch1_l (Conv2D)        (None, None, None, 2 16640       max_pooling2d_l[0][0]
# __________________________________________________________________________________________________
# res2a_branch2c_r (Conv2D)       (None, None, None, 2 16640       activation_51_r[0][0]
# __________________________________________________________________________________________________
# res2a_branch1_r (Conv2D)        (None, None, None, 2 16640       max_pooling2d_1_r[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c_l (BatchNormaliza (None, None, None, 2 1024        res2a_branch2c_l[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1_l (BatchNormalizat (None, None, None, 2 1024        res2a_branch1_l[0][0]
# __________________________________________________________________________________________________
# bn2a_branch2c_r (BatchNormaliza (None, None, None, 2 1024        res2a_branch2c_r[0][0]
# __________________________________________________________________________________________________
# bn2a_branch1_r (BatchNormalizat (None, None, None, 2 1024        res2a_branch1_r[0][0]
# __________________________________________________________________________________________________
# add_l (Add)                     (None, None, None, 2 0           bn2a_branch2c_l[0][0]
#                                                                  bn2a_branch1_l[0][0]
# __________________________________________________________________________________________________
# add_16_r (Add)                  (None, None, None, 2 0           bn2a_branch2c_r[0][0]
#                                                                  bn2a_branch1_r[0][0]
# __________________________________________________________________________________________________
# activation_3_l (Activation)     (None, None, None, 2 0           add_l[0][0]
# __________________________________________________________________________________________________
# activation_52_r (Activation)    (None, None, None, 2 0           add_16_r[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a_l (Conv2D)       (None, None, None, 6 16448       activation_3_l[0][0]
# __________________________________________________________________________________________________
# res2b_branch2a_r (Conv2D)       (None, None, None, 6 16448       activation_52_r[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a_l (BatchNormaliza (None, None, None, 6 256         res2b_branch2a_l[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2a_r (BatchNormaliza (None, None, None, 6 256         res2b_branch2a_r[0][0]
# __________________________________________________________________________________________________
# activation_4_l (Activation)     (None, None, None, 6 0           bn2b_branch2a_l[0][0]
# __________________________________________________________________________________________________
# activation_53_r (Activation)    (None, None, None, 6 0           bn2b_branch2a_r[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b_l (Conv2D)       (None, None, None, 6 36928       activation_4_l[0][0]
# __________________________________________________________________________________________________
# res2b_branch2b_r (Conv2D)       (None, None, None, 6 36928       activation_53_r[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b_l (BatchNormaliza (None, None, None, 6 256         res2b_branch2b_l[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2b_r (BatchNormaliza (None, None, None, 6 256         res2b_branch2b_r[0][0]
# __________________________________________________________________________________________________
# activation_5_l (Activation)     (None, None, None, 6 0           bn2b_branch2b_l[0][0]
# __________________________________________________________________________________________________
# activation_54_r (Activation)    (None, None, None, 6 0           bn2b_branch2b_r[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c_l (Conv2D)       (None, None, None, 2 16640       activation_5_l[0][0]
# __________________________________________________________________________________________________
# res2b_branch2c_r (Conv2D)       (None, None, None, 2 16640       activation_54_r[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c_l (BatchNormaliza (None, None, None, 2 1024        res2b_branch2c_l[0][0]
# __________________________________________________________________________________________________
# bn2b_branch2c_r (BatchNormaliza (None, None, None, 2 1024        res2b_branch2c_r[0][0]
# __________________________________________________________________________________________________
# add_1_l (Add)                   (None, None, None, 2 0           bn2b_branch2c_l[0][0]
#                                                                  activation_3_l[0][0]
# __________________________________________________________________________________________________
# add_17_r (Add)                  (None, None, None, 2 0           bn2b_branch2c_r[0][0]
#                                                                  activation_52_r[0][0]
# __________________________________________________________________________________________________
# activation_6_l (Activation)     (None, None, None, 2 0           add_1_l[0][0]
# __________________________________________________________________________________________________
# activation_55_r (Activation)    (None, None, None, 2 0           add_17_r[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a_l (Conv2D)       (None, None, None, 6 16448       activation_6_l[0][0]
# __________________________________________________________________________________________________
# res2c_branch2a_r (Conv2D)       (None, None, None, 6 16448       activation_55_r[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a_l (BatchNormaliza (None, None, None, 6 256         res2c_branch2a_l[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2a_r (BatchNormaliza (None, None, None, 6 256         res2c_branch2a_r[0][0]
# __________________________________________________________________________________________________
# activation_7_l (Activation)     (None, None, None, 6 0           bn2c_branch2a_l[0][0]
# __________________________________________________________________________________________________
# activation_56_r (Activation)    (None, None, None, 6 0           bn2c_branch2a_r[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b_l (Conv2D)       (None, None, None, 6 36928       activation_7_l[0][0]
# __________________________________________________________________________________________________
# res2c_branch2b_r (Conv2D)       (None, None, None, 6 36928       activation_56_r[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b_l (BatchNormaliza (None, None, None, 6 256         res2c_branch2b_l[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2b_r (BatchNormaliza (None, None, None, 6 256         res2c_branch2b_r[0][0]
# __________________________________________________________________________________________________
# activation_8_l (Activation)     (None, None, None, 6 0           bn2c_branch2b_l[0][0]
# __________________________________________________________________________________________________
# activation_57_r (Activation)    (None, None, None, 6 0           bn2c_branch2b_r[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c_l (Conv2D)       (None, None, None, 2 16640       activation_8_l[0][0]
# __________________________________________________________________________________________________
# res2c_branch2c_r (Conv2D)       (None, None, None, 2 16640       activation_57_r[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c_l (BatchNormaliza (None, None, None, 2 1024        res2c_branch2c_l[0][0]
# __________________________________________________________________________________________________
# bn2c_branch2c_r (BatchNormaliza (None, None, None, 2 1024        res2c_branch2c_r[0][0]
# __________________________________________________________________________________________________
# add_2_l (Add)                   (None, None, None, 2 0           bn2c_branch2c_l[0][0]
#                                                                  activation_6_l[0][0]
# __________________________________________________________________________________________________
# add_18_r (Add)                  (None, None, None, 2 0           bn2c_branch2c_r[0][0]
#                                                                  activation_55_r[0][0]
# __________________________________________________________________________________________________
# activation_9_l (Activation)     (None, None, None, 2 0           add_2_l[0][0]
# __________________________________________________________________________________________________
# activation_58_r (Activation)    (None, None, None, 2 0           add_18_r[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a_l (Conv2D)       (None, None, None, 1 32896       activation_9_l[0][0]
# __________________________________________________________________________________________________
# res3a_branch2a_r (Conv2D)       (None, None, None, 1 32896       activation_58_r[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a_l (BatchNormaliza (None, None, None, 1 512         res3a_branch2a_l[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2a_r (BatchNormaliza (None, None, None, 1 512         res3a_branch2a_r[0][0]
# __________________________________________________________________________________________________
# activation_10_l (Activation)    (None, None, None, 1 0           bn3a_branch2a_l[0][0]
# __________________________________________________________________________________________________
# activation_59_r (Activation)    (None, None, None, 1 0           bn3a_branch2a_r[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b_l (Conv2D)       (None, None, None, 1 147584      activation_10_l[0][0]
# __________________________________________________________________________________________________
# res3a_branch2b_r (Conv2D)       (None, None, None, 1 147584      activation_59_r[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b_l (BatchNormaliza (None, None, None, 1 512         res3a_branch2b_l[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2b_r (BatchNormaliza (None, None, None, 1 512         res3a_branch2b_r[0][0]
# __________________________________________________________________________________________________
# activation_11_l (Activation)    (None, None, None, 1 0           bn3a_branch2b_l[0][0]
# __________________________________________________________________________________________________
# activation_60_r (Activation)    (None, None, None, 1 0           bn3a_branch2b_r[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c_l (Conv2D)       (None, None, None, 5 66048       activation_11_l[0][0]
# __________________________________________________________________________________________________
# res3a_branch1_l (Conv2D)        (None, None, None, 5 131584      activation_9_l[0][0]
# __________________________________________________________________________________________________
# res3a_branch2c_r (Conv2D)       (None, None, None, 5 66048       activation_60_r[0][0]
# __________________________________________________________________________________________________
# res3a_branch1_r (Conv2D)        (None, None, None, 5 131584      activation_58_r[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c_l (BatchNormaliza (None, None, None, 5 2048        res3a_branch2c_l[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1_l (BatchNormalizat (None, None, None, 5 2048        res3a_branch1_l[0][0]
# __________________________________________________________________________________________________
# bn3a_branch2c_r (BatchNormaliza (None, None, None, 5 2048        res3a_branch2c_r[0][0]
# __________________________________________________________________________________________________
# bn3a_branch1_r (BatchNormalizat (None, None, None, 5 2048        res3a_branch1_r[0][0]
# __________________________________________________________________________________________________
# add_3_l (Add)                   (None, None, None, 5 0           bn3a_branch2c_l[0][0]
#                                                                  bn3a_branch1_l[0][0]
# __________________________________________________________________________________________________
# add_19_r (Add)                  (None, None, None, 5 0           bn3a_branch2c_r[0][0]
#                                                                  bn3a_branch1_r[0][0]
# __________________________________________________________________________________________________
# activation_12_l (Activation)    (None, None, None, 5 0           add_3_l[0][0]
# __________________________________________________________________________________________________
# activation_61_r (Activation)    (None, None, None, 5 0           add_19_r[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a_l (Conv2D)       (None, None, None, 1 65664       activation_12_l[0][0]
# __________________________________________________________________________________________________
# res3b_branch2a_r (Conv2D)       (None, None, None, 1 65664       activation_61_r[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a_l (BatchNormaliza (None, None, None, 1 512         res3b_branch2a_l[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2a_r (BatchNormaliza (None, None, None, 1 512         res3b_branch2a_r[0][0]
# __________________________________________________________________________________________________
# activation_13_l (Activation)    (None, None, None, 1 0           bn3b_branch2a_l[0][0]
# __________________________________________________________________________________________________
# activation_62_r (Activation)    (None, None, None, 1 0           bn3b_branch2a_r[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b_l (Conv2D)       (None, None, None, 1 147584      activation_13_l[0][0]
# __________________________________________________________________________________________________
# res3b_branch2b_r (Conv2D)       (None, None, None, 1 147584      activation_62_r[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b_l (BatchNormaliza (None, None, None, 1 512         res3b_branch2b_l[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2b_r (BatchNormaliza (None, None, None, 1 512         res3b_branch2b_r[0][0]
# __________________________________________________________________________________________________
# activation_14_l (Activation)    (None, None, None, 1 0           bn3b_branch2b_l[0][0]
# __________________________________________________________________________________________________
# activation_63_r (Activation)    (None, None, None, 1 0           bn3b_branch2b_r[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c_l (Conv2D)       (None, None, None, 5 66048       activation_14_l[0][0]
# __________________________________________________________________________________________________
# res3b_branch2c_r (Conv2D)       (None, None, None, 5 66048       activation_63_r[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c_l (BatchNormaliza (None, None, None, 5 2048        res3b_branch2c_l[0][0]
# __________________________________________________________________________________________________
# bn3b_branch2c_r (BatchNormaliza (None, None, None, 5 2048        res3b_branch2c_r[0][0]
# __________________________________________________________________________________________________
# add_4_l (Add)                   (None, None, None, 5 0           bn3b_branch2c_l[0][0]
#                                                                  activation_12_l[0][0]
# __________________________________________________________________________________________________
# add_20_r (Add)                  (None, None, None, 5 0           bn3b_branch2c_r[0][0]
#                                                                  activation_61_r[0][0]
# __________________________________________________________________________________________________
# activation_15_l (Activation)    (None, None, None, 5 0           add_4_l[0][0]
# __________________________________________________________________________________________________
# activation_64_r (Activation)    (None, None, None, 5 0           add_20_r[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a_l (Conv2D)       (None, None, None, 1 65664       activation_15_l[0][0]
# __________________________________________________________________________________________________
# res3c_branch2a_r (Conv2D)       (None, None, None, 1 65664       activation_64_r[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a_l (BatchNormaliza (None, None, None, 1 512         res3c_branch2a_l[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2a_r (BatchNormaliza (None, None, None, 1 512         res3c_branch2a_r[0][0]
# __________________________________________________________________________________________________
# activation_16_l (Activation)    (None, None, None, 1 0           bn3c_branch2a_l[0][0]
# __________________________________________________________________________________________________
# activation_65_r (Activation)    (None, None, None, 1 0           bn3c_branch2a_r[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b_l (Conv2D)       (None, None, None, 1 147584      activation_16_l[0][0]
# __________________________________________________________________________________________________
# res3c_branch2b_r (Conv2D)       (None, None, None, 1 147584      activation_65_r[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b_l (BatchNormaliza (None, None, None, 1 512         res3c_branch2b_l[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2b_r (BatchNormaliza (None, None, None, 1 512         res3c_branch2b_r[0][0]
# __________________________________________________________________________________________________
# activation_17_l (Activation)    (None, None, None, 1 0           bn3c_branch2b_l[0][0]
# __________________________________________________________________________________________________
# activation_66_r (Activation)    (None, None, None, 1 0           bn3c_branch2b_r[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c_l (Conv2D)       (None, None, None, 5 66048       activation_17_l[0][0]
# __________________________________________________________________________________________________
# res3c_branch2c_r (Conv2D)       (None, None, None, 5 66048       activation_66_r[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c_l (BatchNormaliza (None, None, None, 5 2048        res3c_branch2c_l[0][0]
# __________________________________________________________________________________________________
# bn3c_branch2c_r (BatchNormaliza (None, None, None, 5 2048        res3c_branch2c_r[0][0]
# __________________________________________________________________________________________________
# add_5_l (Add)                   (None, None, None, 5 0           bn3c_branch2c_l[0][0]
#                                                                  activation_15_l[0][0]
# __________________________________________________________________________________________________
# add_21_r (Add)                  (None, None, None, 5 0           bn3c_branch2c_r[0][0]
#                                                                  activation_64_r[0][0]
# __________________________________________________________________________________________________
# activation_18_l (Activation)    (None, None, None, 5 0           add_5_l[0][0]
# __________________________________________________________________________________________________
# activation_67_r (Activation)    (None, None, None, 5 0           add_21_r[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a_l (Conv2D)       (None, None, None, 1 65664       activation_18_l[0][0]
# __________________________________________________________________________________________________
# res3d_branch2a_r (Conv2D)       (None, None, None, 1 65664       activation_67_r[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a_l (BatchNormaliza (None, None, None, 1 512         res3d_branch2a_l[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2a_r (BatchNormaliza (None, None, None, 1 512         res3d_branch2a_r[0][0]
# __________________________________________________________________________________________________
# activation_19_l (Activation)    (None, None, None, 1 0           bn3d_branch2a_l[0][0]
# __________________________________________________________________________________________________
# activation_68_r (Activation)    (None, None, None, 1 0           bn3d_branch2a_r[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b_l (Conv2D)       (None, None, None, 1 147584      activation_19_l[0][0]
# __________________________________________________________________________________________________
# res3d_branch2b_r (Conv2D)       (None, None, None, 1 147584      activation_68_r[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b_l (BatchNormaliza (None, None, None, 1 512         res3d_branch2b_l[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2b_r (BatchNormaliza (None, None, None, 1 512         res3d_branch2b_r[0][0]
# __________________________________________________________________________________________________
# activation_20_l (Activation)    (None, None, None, 1 0           bn3d_branch2b_l[0][0]
# __________________________________________________________________________________________________
# activation_69_r (Activation)    (None, None, None, 1 0           bn3d_branch2b_r[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c_l (Conv2D)       (None, None, None, 5 66048       activation_20_l[0][0]
# __________________________________________________________________________________________________
# res3d_branch2c_r (Conv2D)       (None, None, None, 5 66048       activation_69_r[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c_l (BatchNormaliza (None, None, None, 5 2048        res3d_branch2c_l[0][0]
# __________________________________________________________________________________________________
# bn3d_branch2c_r (BatchNormaliza (None, None, None, 5 2048        res3d_branch2c_r[0][0]
# __________________________________________________________________________________________________
# add_6_l (Add)                   (None, None, None, 5 0           bn3d_branch2c_l[0][0]
#                                                                  activation_18_l[0][0]
# __________________________________________________________________________________________________
# add_22_r (Add)                  (None, None, None, 5 0           bn3d_branch2c_r[0][0]
#                                                                  activation_67_r[0][0]
# __________________________________________________________________________________________________
# activation_21_l (Activation)    (None, None, None, 5 0           add_6_l[0][0]
# __________________________________________________________________________________________________
# activation_70_r (Activation)    (None, None, None, 5 0           add_22_r[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a_l (Conv2D)       (None, None, None, 2 131328      activation_21_l[0][0]
# __________________________________________________________________________________________________
# res4a_branch2a_r (Conv2D)       (None, None, None, 2 131328      activation_70_r[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a_l (BatchNormaliza (None, None, None, 2 1024        res4a_branch2a_l[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2a_r (BatchNormaliza (None, None, None, 2 1024        res4a_branch2a_r[0][0]
# __________________________________________________________________________________________________
# activation_22_l (Activation)    (None, None, None, 2 0           bn4a_branch2a_l[0][0]
# __________________________________________________________________________________________________
# activation_71_r (Activation)    (None, None, None, 2 0           bn4a_branch2a_r[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b_l (Conv2D)       (None, None, None, 2 590080      activation_22_l[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b_r (Conv2D)       (None, None, None, 2 590080      activation_71_r[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b_l (BatchNormaliza (None, None, None, 2 1024        res4a_branch2b_l[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b_r (BatchNormaliza (None, None, None, 2 1024        res4a_branch2b_r[0][0]
# __________________________________________________________________________________________________
# activation_23_l (Activation)    (None, None, None, 2 0           bn4a_branch2b_l[0][0]
# __________________________________________________________________________________________________
# activation_72_r (Activation)    (None, None, None, 2 0           bn4a_branch2b_r[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c_l (Conv2D)       (None, None, None, 1 263168      activation_23_l[0][0]
# __________________________________________________________________________________________________
# res4a_branch1_l (Conv2D)        (None, None, None, 1 525312      activation_21_l[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c_r (Conv2D)       (None, None, None, 1 263168      activation_72_r[0][0]
# __________________________________________________________________________________________________
# res4a_branch1_r (Conv2D)        (None, None, None, 1 525312      activation_70_r[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c_l (BatchNormaliza (None, None, None, 1 4096        res4a_branch2c_l[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1_l (BatchNormalizat (None, None, None, 1 4096        res4a_branch1_l[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c_r (BatchNormaliza (None, None, None, 1 4096        res4a_branch2c_r[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1_r (BatchNormalizat (None, None, None, 1 4096        res4a_branch1_r[0][0]
# __________________________________________________________________________________________________
# add_7_l (Add)                   (None, None, None, 1 0           bn4a_branch2c_l[0][0]
#                                                                  bn4a_branch1_l[0][0]
# __________________________________________________________________________________________________
# add_23_r (Add)                  (None, None, None, 1 0           bn4a_branch2c_r[0][0]
#                                                                  bn4a_branch1_r[0][0]
# __________________________________________________________________________________________________
# activation_24_l (Activation)    (None, None, None, 1 0           add_7_l[0][0]
# __________________________________________________________________________________________________
# activation_73_r (Activation)    (None, None, None, 1 0           add_23_r[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a_l (Conv2D)       (None, None, None, 2 262400      activation_24_l[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a_r (Conv2D)       (None, None, None, 2 262400      activation_73_r[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a_l (BatchNormaliza (None, None, None, 2 1024        res4b_branch2a_l[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a_r (BatchNormaliza (None, None, None, 2 1024        res4b_branch2a_r[0][0]
# __________________________________________________________________________________________________
# activation_25_l (Activation)    (None, None, None, 2 0           bn4b_branch2a_l[0][0]
# __________________________________________________________________________________________________
# activation_74_r (Activation)    (None, None, None, 2 0           bn4b_branch2a_r[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b_l (Conv2D)       (None, None, None, 2 590080      activation_25_l[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b_r (Conv2D)       (None, None, None, 2 590080      activation_74_r[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b_l (BatchNormaliza (None, None, None, 2 1024        res4b_branch2b_l[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b_r (BatchNormaliza (None, None, None, 2 1024        res4b_branch2b_r[0][0]
# __________________________________________________________________________________________________
# activation_26_l (Activation)    (None, None, None, 2 0           bn4b_branch2b_l[0][0]
# __________________________________________________________________________________________________
# activation_75_r (Activation)    (None, None, None, 2 0           bn4b_branch2b_r[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c_l (Conv2D)       (None, None, None, 1 263168      activation_26_l[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c_r (Conv2D)       (None, None, None, 1 263168      activation_75_r[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c_l (BatchNormaliza (None, None, None, 1 4096        res4b_branch2c_l[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c_r (BatchNormaliza (None, None, None, 1 4096        res4b_branch2c_r[0][0]
# __________________________________________________________________________________________________
# add_8_l (Add)                   (None, None, None, 1 0           bn4b_branch2c_l[0][0]
#                                                                  activation_24_l[0][0]
# __________________________________________________________________________________________________
# add_24_r (Add)                  (None, None, None, 1 0           bn4b_branch2c_r[0][0]
#                                                                  activation_73_r[0][0]
# __________________________________________________________________________________________________
# activation_27_l (Activation)    (None, None, None, 1 0           add_8_l[0][0]
# __________________________________________________________________________________________________
# activation_76_r (Activation)    (None, None, None, 1 0           add_24_r[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a_l (Conv2D)       (None, None, None, 2 262400      activation_27_l[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a_r (Conv2D)       (None, None, None, 2 262400      activation_76_r[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a_l (BatchNormaliza (None, None, None, 2 1024        res4c_branch2a_l[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a_r (BatchNormaliza (None, None, None, 2 1024        res4c_branch2a_r[0][0]
# __________________________________________________________________________________________________
# activation_28_l (Activation)    (None, None, None, 2 0           bn4c_branch2a_l[0][0]
# __________________________________________________________________________________________________
# activation_77_r (Activation)    (None, None, None, 2 0           bn4c_branch2a_r[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b_l (Conv2D)       (None, None, None, 2 590080      activation_28_l[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b_r (Conv2D)       (None, None, None, 2 590080      activation_77_r[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b_l (BatchNormaliza (None, None, None, 2 1024        res4c_branch2b_l[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b_r (BatchNormaliza (None, None, None, 2 1024        res4c_branch2b_r[0][0]
# __________________________________________________________________________________________________
# activation_29_l (Activation)    (None, None, None, 2 0           bn4c_branch2b_l[0][0]
# __________________________________________________________________________________________________
# activation_78_r (Activation)    (None, None, None, 2 0           bn4c_branch2b_r[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c_l (Conv2D)       (None, None, None, 1 263168      activation_29_l[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c_r (Conv2D)       (None, None, None, 1 263168      activation_78_r[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c_l (BatchNormaliza (None, None, None, 1 4096        res4c_branch2c_l[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c_r (BatchNormaliza (None, None, None, 1 4096        res4c_branch2c_r[0][0]
# __________________________________________________________________________________________________
# add_9_l (Add)                   (None, None, None, 1 0           bn4c_branch2c_l[0][0]
#                                                                  activation_27_l[0][0]
# __________________________________________________________________________________________________
# add_25_r (Add)                  (None, None, None, 1 0           bn4c_branch2c_r[0][0]
#                                                                  activation_76_r[0][0]
# __________________________________________________________________________________________________
# activation_30_l (Activation)    (None, None, None, 1 0           add_9_l[0][0]
# __________________________________________________________________________________________________
# activation_79_r (Activation)    (None, None, None, 1 0           add_25_r[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a_l (Conv2D)       (None, None, None, 2 262400      activation_30_l[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a_r (Conv2D)       (None, None, None, 2 262400      activation_79_r[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a_l (BatchNormaliza (None, None, None, 2 1024        res4d_branch2a_l[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a_r (BatchNormaliza (None, None, None, 2 1024        res4d_branch2a_r[0][0]
# __________________________________________________________________________________________________
# activation_31_l (Activation)    (None, None, None, 2 0           bn4d_branch2a_l[0][0]
# ...
# res5a_branch2a_l (Conv2D)       (None, None, None, 5 524800      activation_39_l[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a_r (Conv2D)       (None, None, None, 5 524800      activation_88_r[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a_l (BatchNormaliza (None, None, None, 5 2048        res5a_branch2a_l[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a_r (BatchNormaliza (None, None, None, 5 2048        res5a_branch2a_r[0][0]
# __________________________________________________________________________________________________
# activation_40_l (Activation)    (None, None, None, 5 0           bn5a_branch2a_l[0][0]
# __________________________________________________________________________________________________
# activation_89_r (Activation)    (None, None, None, 5 0           bn5a_branch2a_r[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b_l (Conv2D)       (None, None, None, 5 2359808     activation_40_l[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b_r (Conv2D)       (None, None, None, 5 2359808     activation_89_r[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b_l (BatchNormaliza (None, None, None, 5 2048        res5a_branch2b_l[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b_r (BatchNormaliza (None, None, None, 5 2048        res5a_branch2b_r[0][0]
# __________________________________________________________________________________________________
# activation_41_l (Activation)    (None, None, None, 5 0           bn5a_branch2b_l[0][0]
# __________________________________________________________________________________________________
# activation_90_r (Activation)    (None, None, None, 5 0           bn5a_branch2b_r[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c_l (Conv2D)       (None, None, None, 2 1050624     activation_41_l[0][0]
# __________________________________________________________________________________________________
# res5a_branch1_l (Conv2D)        (None, None, None, 2 2099200     activation_39_l[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c_r (Conv2D)       (None, None, None, 2 1050624     activation_90_r[0][0]
# __________________________________________________________________________________________________
# res5a_branch1_r (Conv2D)        (None, None, None, 2 2099200     activation_88_r[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c_l (BatchNormaliza (None, None, None, 2 8192        res5a_branch2c_l[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1_l (BatchNormalizat (None, None, None, 2 8192        res5a_branch1_l[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c_r (BatchNormaliza (None, None, None, 2 8192        res5a_branch2c_r[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1_r (BatchNormalizat (None, None, None, 2 8192        res5a_branch1_r[0][0]
# __________________________________________________________________________________________________
# add_13_l (Add)                  (None, None, None, 2 0           bn5a_branch2c_l[0][0]
#                                                                  bn5a_branch1_l[0][0]
# __________________________________________________________________________________________________
# add_29_r (Add)                  (None, None, None, 2 0           bn5a_branch2c_r[0][0]
#                                                                  bn5a_branch1_r[0][0]
# __________________________________________________________________________________________________
# activation_42_l (Activation)    (None, None, None, 2 0           add_13_l[0][0]
# __________________________________________________________________________________________________
# activation_91_r (Activation)    (None, None, None, 2 0           add_29_r[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a_l (Conv2D)       (None, None, None, 5 1049088     activation_42_l[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a_r (Conv2D)       (None, None, None, 5 1049088     activation_91_r[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a_l (BatchNormaliza (None, None, None, 5 2048        res5b_branch2a_l[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a_r (BatchNormaliza (None, None, None, 5 2048        res5b_branch2a_r[0][0]
# __________________________________________________________________________________________________
# activation_43_l (Activation)    (None, None, None, 5 0           bn5b_branch2a_l[0][0]
# __________________________________________________________________________________________________
# activation_92_r (Activation)    (None, None, None, 5 0           bn5b_branch2a_r[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b_l (Conv2D)       (None, None, None, 5 2359808     activation_43_l[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b_r (Conv2D)       (None, None, None, 5 2359808     activation_92_r[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b_l (BatchNormaliza (None, None, None, 5 2048        res5b_branch2b_l[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b_r (BatchNormaliza (None, None, None, 5 2048        res5b_branch2b_r[0][0]
# __________________________________________________________________________________________________
# activation_44_l (Activation)    (None, None, None, 5 0           bn5b_branch2b_l[0][0]
# __________________________________________________________________________________________________
# activation_93_r (Activation)    (None, None, None, 5 0           bn5b_branch2b_r[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c_l (Conv2D)       (None, None, None, 2 1050624     activation_44_l[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c_r (Conv2D)       (None, None, None, 2 1050624     activation_93_r[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c_l (BatchNormaliza (None, None, None, 2 8192        res5b_branch2c_l[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c_r (BatchNormaliza (None, None, None, 2 8192        res5b_branch2c_r[0][0]
# __________________________________________________________________________________________________
# add_14_l (Add)                  (None, None, None, 2 0           bn5b_branch2c_l[0][0]
#                                                                  activation_42_l[0][0]
# __________________________________________________________________________________________________
# add_30_r (Add)                  (None, None, None, 2 0           bn5b_branch2c_r[0][0]
#                                                                  activation_91_r[0][0]
# __________________________________________________________________________________________________
# activation_45_l (Activation)    (None, None, None, 2 0           add_14_l[0][0]
# __________________________________________________________________________________________________
# activation_94_r (Activation)    (None, None, None, 2 0           add_30_r[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a_l (Conv2D)       (None, None, None, 5 1049088     activation_45_l[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a_r (Conv2D)       (None, None, None, 5 1049088     activation_94_r[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a_l (BatchNormaliza (None, None, None, 5 2048        res5c_branch2a_l[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a_r (BatchNormaliza (None, None, None, 5 2048        res5c_branch2a_r[0][0]
# __________________________________________________________________________________________________
# activation_46_l (Activation)    (None, None, None, 5 0           bn5c_branch2a_l[0][0]
# __________________________________________________________________________________________________
# activation_95_r (Activation)    (None, None, None, 5 0           bn5c_branch2a_r[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b_l (Conv2D)       (None, None, None, 5 2359808     activation_46_l[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b_r (Conv2D)       (None, None, None, 5 2359808     activation_95_r[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b_l (BatchNormaliza (None, None, None, 5 2048        res5c_branch2b_l[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b_r (BatchNormaliza (None, None, None, 5 2048        res5c_branch2b_r[0][0]
# __________________________________________________________________________________________________
# activation_47_l (Activation)    (None, None, None, 5 0           bn5c_branch2b_l[0][0]
# __________________________________________________________________________________________________
# activation_96_r (Activation)    (None, None, None, 5 0           bn5c_branch2b_r[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c_l (Conv2D)       (None, None, None, 2 1050624     activation_47_l[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c_r (Conv2D)       (None, None, None, 2 1050624     activation_96_r[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c_l (BatchNormaliza (None, None, None, 2 8192        res5c_branch2c_l[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c_r (BatchNormaliza (None, None, None, 2 8192        res5c_branch2c_r[0][0]
# __________________________________________________________________________________________________
# add_15_l (Add)                  (None, None, None, 2 0           bn5c_branch2c_l[0][0]
#                                                                  activation_45_l[0][0]
# __________________________________________________________________________________________________
# add_31_r (Add)                  (None, None, None, 2 0           bn5c_branch2c_r[0][0]
#                                                                  activation_94_r[0][0]
# __________________________________________________________________________________________________
# activation_48_l (Activation)    (None, None, None, 2 0           add_15_l[0][0]
# __________________________________________________________________________________________________
# activation_97_r (Activation)    (None, None, None, 2 0           add_31_r[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_l (Glo (None, 2048)         0           activation_48_l[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1_r (G (None, 2048)         0           activation_97_r[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 4096)         0           global_average_pooling2d_l[0][0]
#                                                                  global_average_pooling2d_1_r[0][0
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 4096)         0           concatenate[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          2097664     dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 512)          2048        dense[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 512)          0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          262656      activation_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 512)          2048        dense_1[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 512)          0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           activation_99[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 8)            4104        dropout_1[0][0]
# ==================================================================================================
# Total params: 49,543,944
# Trainable params: 49,435,656
# Non-trainable params: 108,288
# __________________________________________________________________________________________________

# %%
def binary_focal_loss(gamma=2., alpha=.25):

    def binary_focal_loss_fixed(y_true, y_pred):
        pt_1 = tf.where(tf.equal(y_true, 1), y_pred, tf.ones_like(y_pred))
        pt_0 = tf.where(tf.equal(y_true, 0), y_pred, tf.zeros_like(y_pred))

        epsilon = K.epsilon()
        # clip to prevent NaN's and Inf's
        pt_1 = K.clip(pt_1, epsilon, 1. - epsilon)
        pt_0 = K.clip(pt_0, epsilon, 1. - epsilon)

        return -K.sum(alpha * K.pow(1. - pt_1, gamma) * K.log(pt_1)) \
               -K.sum((1 - alpha) * K.pow(pt_0, gamma) * K.log(1. - pt_0))

    return binary_focal_loss_fixed

# %%
loss = 'binary_crossentropy'

model.compile(loss=binary_focal_loss(), optimizer=keras.optimizers.Adam(1e-5), metrics=['accuracy'])
# Out:
# W1104 18:19:08.971496 20084 deprecation.py:323] From <ipython-input-17-26f28ccc265d>:4: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
er = EarlyStopping(monitor='val_loss', patience=10)
checkpoint = ModelCheckpoint('./snapshots/baseline/model.h5', save_best_only=True)
reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=7)

callbacks = [er, checkpoint, reduce]

# %%
batch_size = 8
epoch = 200

# Train test split
train, test = train_test_split(df, test_size=0.2, random_state=85)

train_img_gen = image_generator(train, batch_size)
test_img_gen = image_generator(test, batch_size)

# %%
STEP_PER_EPOCH = len(train) // batch_size
STEP_PER_EPOCH_VAL = len(test) // batch_size
model.fit_generator(train_img_gen,
                    steps_per_epoch=STEP_PER_EPOCH,
                    validation_data=test_img_gen,
                    validation_steps=STEP_PER_EPOCH_VAL,
                    callbacks=callbacks,
                    epochs=epoch)
# Out:
# Epoch 1/200
# 350/350 [==============================] - 522s 1s/step - loss: 10.9779 - acc: 0.2407 - val_loss: 0.3401 - val_acc: 1.0000
# Epoch 2/200
# 350/350 [==============================] - 410s 1s/step - loss: 5.7195 - acc: 0.5696 - val_loss: 4.4375 - val_acc: 0.0000e+00
# Epoch 3/200
# 350/350 [==============================] - 405s 1s/step - loss: 3.1245 - acc: 0.8221 - val_loss: 13.7005 - val_acc: 0.0000e+00
# Epoch 4/200
# 350/350 [==============================] - 399s 1s/step - loss: 1.8878 - acc: 0.9293 - val_loss: 10.0246 - val_acc: 0.0000e+00
# Epoch 5/200
# 350/350 [==============================] - 397s 1s/step - loss: 1.2266 - acc: 0.9736 - val_loss: 14.4571 - val_acc: 0.0000e+00
# Epoch 6/200
# 350/350 [==============================] - 403s 1s/step - loss: 0.8521 - acc: 0.9889 - val_loss: 9.7240 - val_acc: 0.0000e+00
# Epoch 7/200
# 350/350 [==============================] - 405s 1s/step - loss: 0.5842 - acc: 0.9936 - val_loss: 12.4067 - val_acc: 0.0000e+00
# Epoch 8/200
# 350/350 [==============================] - 402s 1s/step - loss: 0.4056 - acc: 0.9986 - val_loss: 16.3820 - val_acc: 0.0000e+00
# Epoch 9/200
# 350/350 [==============================] - 419s 1s/step - loss: 0.3577 - acc: 1.0000 - val_loss: 16.1725 - val_acc: 0.0000e+00
# Epoch 10/200
# 350/350 [==============================] - 416s 1s/step - loss: 0.3321 - acc: 0.9996 - val_loss: 16.2383 - val_acc: 0.0000e+00
# Epoch 11/200
# 350/350 [==============================] - 398s 1s/step - loss: 0.3148 - acc: 1.0000 - val_loss: 16.8142 - val_acc: 0.0000e+00

# %%
model = load_model = './snapshots/baseline/model.h5'
